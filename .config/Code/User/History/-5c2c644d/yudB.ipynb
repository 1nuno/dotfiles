# %%
import requests as r
from bs4 import BeautifulSoup as bs
from lxml import etree

# %%
session = r.Session()
cedula = "exemplo"
a = session.get(f"https://portal.oa.pt/advogados/pesquisa-de-advogados/?l=&cg=&ce={cedula}C&n=&lo=&m=&cp=&op=&o=0&g-recaptcha-response=")
soup = bs(a.text,'html.parser')
dom = etree.HTML(str(soup))

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <link href="/media/114633/logo_2.png?anchor=center&amp;mode=crop&amp;width=16&amp;height=16&amp;rnd=131112568250000000" rel="icon" type="image/png"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0" name="viewport">
# <link href="https://portal.oa.pt/advogados/pesquisa-de-advogados/" rel="canonical">
# <title>Pesquisa de Advogados - Ordem dos Advogados</title> <meta content="website" property="og:type"/>
# <meta content="Pesquisa de Advogados - Ordem dos Advogados" property="og:title">
# <meta content="" property="og:image">
# <meta content="https://portal.oa.pt/advogados/pesquisa-de-advogados/" property="og:url"/>
# <meta content="" property="og:description"/>
# <meta content="Ordem dos Advogados" property="og:site_name"/>
# <title>Ordem dos Advogados - Homepage</title>
# <!-- Modernizr -->
# ...

# %%
dom.xpath('//h3[@class="search-results__summary-title red title"]')
# Out:
# []

# %%
dom.xpath('//h3//text()')
# Out:
# ['0   resultados']
