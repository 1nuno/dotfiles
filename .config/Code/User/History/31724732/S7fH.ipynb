# %%
import pandas as pd

# %%
df = pd.read_csv('test_data.csv')
df = df.rename(columns={
    "item_id": "id", 
    "": "datetime",
    "Mean": "mean_temp"
})

# %%
#category
df.loc[:,['category']].rename(columns={"category": "name"})

# %%
#manufacturer
df.loc[:,['manufacturer']].rename(columns={"manufacturer": "name"})

# %%
#product
df.loc[:,['item_id',
          'name',
          'category',
          'price',
          'stock',
          'description',
          'manufacturer',
          'weight',
          'image_url']].rename(columns={"item_id": "id"})
# Out:
#     id    name     category  price  stock                  description  \
# 0    1  Item A         Food   9.99   1000             Premium pet food
# 1    2  Item B         Toys   5.99    500     Interactive toy for pets
# 2    3  Item C  Accessories  12.99    300          Pet collar for dogs
# 3    4  Item D         Food   7.49    750             Healthy cat food
# 4    5  Item E         Toys   3.49    800         Catnip ball for cats
# 5    6  Item F  Accessories   8.99    450           Pet leash for dogs
# 6    7  Item G         Food   6.79    600        High-protein dog food
# 7    8  Item H         Toys   4.29    350    Squeaky chew toy for dogs
# 8    9  Item I  Accessories  15.49    200             Cat grooming kit
# 9   10  Item J         Food  10.99    900             Organic cat food
# 10  11  Item K         Toys   6.59    400  Interactive treat dispenser
# 11  12  Item L  Accessories  14.99    250       Pet bed for small dogs
# ...

# %%
df
# Out:
#     item_id    name     category  price  stock                  description  \
# 0         1  Item A         Food   9.99   1000             Premium pet food
# 1         2  Item B         Toys   5.99    500     Interactive toy for pets
# 2         3  Item C  Accessories  12.99    300          Pet collar for dogs
# 3         4  Item D         Food   7.49    750             Healthy cat food
# 4         5  Item E         Toys   3.49    800         Catnip ball for cats
# 5         6  Item F  Accessories   8.99    450           Pet leash for dogs
# 6         7  Item G         Food   6.79    600        High-protein dog food
# 7         8  Item H         Toys   4.29    350    Squeaky chew toy for dogs
# 8         9  Item I  Accessories  15.49    200             Cat grooming kit
# 9        10  Item J         Food  10.99    900             Organic cat food
# 10       11  Item K         Toys   6.59    400  Interactive treat dispenser
# ...
