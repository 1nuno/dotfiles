# %%
import numpy as np
import matplotlib.pyplot as plt
srate = 100

start_time = -2
end_time = 2

time = np.arange(start_time, end_time, 1/srate)

time[0:10]
# Out:
# array([-2.  , -1.99, -1.98, -1.97, -1.96, -1.95, -1.94, -1.93, -1.92,
#        -1.91])

# %%
def create_signal(x):
    y = np.sin(2 * np.pi * x)
    return y
signal = create_signal(time)

plt.plot(time,signal)
plt.xlabel('Time (sec)')
plt.ylabel('Amplitude')
plt.grid()
plt.show()

# %%
w0 = 10*np.pi
f0 = w0/(2*np.pi)
T0 = 1/f0

k = 1

fs = k*f0
Ts = 1/fs

srate = fs
start_time = -2*T0
end_time = 2*T0

continuous_time = np.arange(start_time,end_time, 1/(srate*1000))
continuous_signal = np.cos(10*np.pi*continuous_time)

time = np.arange(start_time,end_time, 1/srate)
signal = np.cos(10*np.pi*time)

plt.plot(continuous_time,continuous_signal)
plt.plot(time,signal, 'ro')
plt.xlabel('Time (sec)')
plt.ylabel('Amplitude')
plt.grid()
plt.show()

# %% [markdown]
# # Energia de sinal aperiodico

# %%
def func(n):
    return (n + 2)**2
N = np.arange(-4,3)
np.sum(list(map(func,N)))
# Out:
# 35

# %%
(3/5)/(2+2*(3/5))
# Out:
# 0.18749999999999997

# %%
9/80
# Out:
# 0.1125
